# %%
import qiskit

# %%
from qiskit import *

# %%
from qiskit import Aer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-5cf2fb0b7167> in <module>()
# ----> 1 from qiskit import Aer
#
# ImportError: cannot import name 'Aer' from 'qiskit' (unknown location)
